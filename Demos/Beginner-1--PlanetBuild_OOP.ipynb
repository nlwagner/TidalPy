# %% [markdown]
# # Building Planets with TidalPy
# In this notebook we will see how we can use TidalPy's object oriented approach to build a layered planet.

# %%
from pprint import pprint
from TidalPy.structures import build_world

# Turn this variable to True if you would like to learn more about TidalPy World's dictionary structure
print_configs = False

# %% [markdown]
# ### 2-Layer Layered World
# First we will start with a simple planet with only two layers. We will assume that the density of these layers does not depend on pressure.

# %%
io_simple = build_world('io_simple')
if print_configs:
    pprint(io_simple.config)
_ = io_simple.paint()

# %% [markdown]
# ### 4-layer Layered World
# Next we will look at a slightly more complicated planet that has four layers, but we keep the assumption that density does not change with pressure.

# %%
earth_simple = build_world('earth_simple')
if print_configs:
    pprint(earth_simple.config)
_ = earth_simple.paint()

# %% [markdown]
# ### 4-layer Burnman World
# Finally, we will look a more realistic version of an Earth model where we use the Burnman package to calculate a self-consistent interior structure. Density will change with pressure and temperature. The functional form of this relationship depends on the equation of state which is different for each layer.

# %%
earth = build_world('earth')
if print_configs:
    pprint(earth.config['layers'])
_ = earth.paint()
# Out:
# 2024-02-14 12:47:13(+00:01:00::478904) - WARNING  : BurnMan installation can not be found. TidalPy's BurnMan extension functions can not be used.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 earth = build_world('earth')
#       2 if print_configs:
#       3     pprint(earth.config['layers'])
#
# File ~/opt/anaconda3/envs/tidalpy/lib/python3.9/site-packages/TidalPy/structures/world_builder/world_builder.py:87, in build_world(world_name, world_config)
#      84 from TidalPy.Extending.burnman import build_burnman_world, BurnManWorld
#      86 log.debug('Attempting to build the BurnMan class for the world.')
# ---> 87 burnman_world, burnman_layers = build_burnman_world(world_config)
#      88 log.debug(f'Burnman world building completed!')
#      90 log.debug('Installing Burnman world into TidalPy world class.')
#
# File ~/opt/anaconda3/envs/tidalpy/lib/python3.9/site-packages/TidalPy/Extending/burnman/build.py:135, in build_burnman_world(planet_config, verbose)
#     133 if not burnman_installed:
#     134     log.debug(f"Burnman install not found.")
# --> 135     raise ImportError('Burnman package not found.')
#     137 # Store Layer information
#     138 try:
#
# ImportError: Burnman package not found.
